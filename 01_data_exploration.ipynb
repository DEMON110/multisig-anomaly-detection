# %% [markdown]
# # 01: Data Exploration
#
# Explores the Ethereum multisig dataset.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../data/processed/labeled_transactions.csv')
print(f'Dataset: {len(df)} transactions')
